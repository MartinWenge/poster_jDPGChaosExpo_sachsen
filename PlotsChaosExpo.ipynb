# %%
dataBorder = [[4,591.4], [8,642.9], [16,718.2],[32,780.1],[64,843.1],[172,945.5],[1150,1251.8]]

# %%
import matplotlib.pyplot as plt

# %%
plt.figure()
plt.xlabel("Anzahl Stützpunkte")
plt.ylabel("Länge der Grenze / km")
plt.plot(dataBorderx,dataBordery, 'ro')

# %%
dataBorderx=[ x[0] for x in dataBorder]

# %%
dataBorderx
# Out:
# [4, 8, 16, 32, 64, 172, 1150]

# %%
dataBordery=[ x[1] for x in dataBorder]

# %%
dataBordery
# Out:
# [591.4, 642.9, 718.2, 780.1, 843.1, 945.5, 1251.8]

# %%
plt.figure(dpi=300)
plt.xlabel("Anzahl Stützpunkte",fontsize=18)
plt.ylabel("Länge der Grenze / km",fontsize=18)
ax = plt.gca()
#ax.set_facecolor((0.75390625,0.765625,0.83203125)) # IPFblau
#ax.set_facecolor((255/256.0,153/256.0,0/256.0) # IPForange
#ax.set_facecolor('#FCE885')
plt.semilogx(dataBorderx,dataBordery, 'o-', mew=4.0,color='#00BFFF')
plt.show()
